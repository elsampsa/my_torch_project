# %%
# %reload_ext autoreload
# %autoreload 2
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from random import randint
import cv2
import glob, os
from pprint import pprint
# %matplotlib inline
mpl.rcParams['figure.figsize'] = [100, 40]
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
mpl.rcParams.update(params)

# %%
from gendata import *
from dataset import BasicDataset

# %%
img, mask = genGauge(120, 0.9, val = 0.8)

# %%
img = modImage(img)

# %%
img.min(), img.max()
# Out:
# (0.1024777462431433, 0.9593812671016233)

# %%
plt.imshow(img, 'gray')

# %%
plt.imshow(mask, 'binary')

# %%
mask.min(), mask.max()
# Out:
# (0.0, 1.0)

# %%
writeImage("img.png", img)
writeImage("mask.png", mask)

# %%
img = readImage("img.png")
print(img.min(), img.max())
plt.imshow(img, 'gray')
# Out:
# 0.10196078431372549 0.9568627450980393

# %%
mask = readImage("mask.png")
print(mask.min(), mask.max())
plt.imshow(mask, 'gray')
# Out:
# 0.0 1.0

# %%
mask = BasicDataset.readImage("mask.png") # returns tensor
mask = mask.numpy()
mask.resize(120, 120)
print(mask.min(), mask.max())
plt.imshow(mask, 'gray')
# Out:
# 0.0 1.0

# %%
mask[(mask!=0)*(mask!=1)] # check there are no weird values..
# Out:
# array([], dtype=float32)

# %%
mask = BasicDataset.readImage("img.png") # returns tensor
mask = mask.numpy()
mask.resize(120, 120)
print(mask.min(), mask.max())
plt.imshow(mask, 'gray')
# Out:
# 0.10655738 1.0
