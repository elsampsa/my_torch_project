# %%
# %reload_ext autoreload
# %autoreload 2
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from random import randint
import cv2
import glob, os
from pprint import pprint
# %matplotlib inline
mpl.rcParams['figure.figsize'] = [100, 40]
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
mpl.rcParams.update(params)

# %%
from dataset import BasicDataset

# %%
ds = BasicDataset(
        #os.path.join(os.environ["PWD"],"data", "imgs"),
        #os.path.join(os.environ["PWD"],"data", "masks"),
        os.path.join("data", "imgs"),
        os.path.join("data", "masks")
    )
# Out:
# Reading dataset with 3000 examples

# %%
i = 0
pair = ds[i]
image = pair["image"].numpy()
image.resize(120, 120)
mask = pair["mask"].numpy()
mask.resize(120, 120)

# %%
plt.imshow(image, 'gray')

# %%
plt.imshow(mask, 'gray')

# %%
print(mask.min(), mask.max())
# Out:
# 0.0 1.0

# %%
print(image.min(), image.max())
# Out:
# 0.32894737 1.0

# %%
mask[(mask!=0)*(mask!=1)] # check there are no weird values..
# Out:
# array([], dtype=float32)

# %%
plt.imshow(255 - image, 'gray')

# %%
for i in range(1,20):
    pair = ds[i]
    image = pair["image"].numpy()
    image.resize(120, 120)
    # mask = pair["mask"].numpy()
    plt.figure()
    plt.imshow(255 - image, 'gray')
